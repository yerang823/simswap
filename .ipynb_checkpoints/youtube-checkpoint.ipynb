# %%
url = 'https://youtu.be/9_H8gsr_Dys'

start = '00:00:45'
end = '00:01:08'

from pytube import YouTube
DOWNLOAD_FOLDER = "./downloads"
yt = YouTube(url)
stream = yt.streams.get_highest_resolution()
#stream = yt.streams.filter(progressive=True).last()

stream.download(DOWNLOAD_FOLDER, filename='temp.mp4')

# !rm ./downloads/output.mp4

# !ffmpeg -i ./downloads/temp.mp4 -ss $start -to $end ./downloads/output.mp4
# !rm ./downloads/temp.mp4
# Out:
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 10.3.0 (GCC)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1649114005999/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1649114005999/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1649114005999/_build_env/bin/pkg-config
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './downloads/temp.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-01-05T06:19:17.000000Z
#   Duration: 00:13:37.69, start: 0.000000, bitrate: 1224 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 1093 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2022-01-05T06:19:17.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 01/04/2022.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-01-05T06:19:17.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 01/04/2022.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x557f7762f0c0] using SAR=1/1
# [libx264 @ 0x557f7762f0c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x557f7762f0c0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x557f7762f0c0] 264 - core 161 r3030M 8bd6d28 - H.264/MPEG-4 AVC codec - Copyleft 2003-2020 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=22 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './downloads/output.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf59.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2022-01-05T06:19:17.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 01/04/2022.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2022-01-05T06:19:17.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 01/04/2022.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.18.100 aac
# frame=  690 fps=186 q=-1.0 Lsize=    3101kB time=00:00:23.01 bitrate=1104.0kbits/s speed=6.19x
# video:2717kB audio:358kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.842764%
# [libx264 @ 0x557f7762f0c0] frame I:3     Avg QP:20.05  size:126632
# [libx264 @ 0x557f7762f0c0] frame P:175   Avg QP:21.85  size:  9368
# [libx264 @ 0x557f7762f0c0] frame B:512   Avg QP:29.60  size:  1488
# [libx264 @ 0x557f7762f0c0] consecutive B-frames:  0.6%  1.2%  0.9% 97.4%
# [libx264 @ 0x557f7762f0c0] mb I  I16..4:  6.7% 28.5% 64.8%
# [libx264 @ 0x557f7762f0c0] mb P  I16..4:  0.3%  1.4%  0.8%  P16..4: 18.9%  6.2%  5.0%  0.0%  0.0%    skip:67.5%
# [libx264 @ 0x557f7762f0c0] mb B  I16..4:  0.0%  0.2%  0.1%  B16..8: 11.5%  1.6%  0.5%  direct: 0.4%  skip:85.7%  L0:39.1% L1:52.9% BI: 8.0%
# [libx264 @ 0x557f7762f0c0] 8x8 transform intra:48.6% inter:62.2%
# [libx264 @ 0x557f7762f0c0] coded y,uvDC,uvAC intra: 78.5% 79.5% 40.9% inter: 4.2% 3.5% 0.2%
# [libx264 @ 0x557f7762f0c0] i16 v,h,dc,p: 35% 37%  4% 25%
# [libx264 @ 0x557f7762f0c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 17% 11%  5%  7%  8%  8%  9%  8%
# [libx264 @ 0x557f7762f0c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 25%  8%  4%  5%  5%  5%  5%  4%
# [libx264 @ 0x557f7762f0c0] i8c dc,h,v,p: 36% 26% 29%  9%
# [libx264 @ 0x557f7762f0c0] Weighted P-Frames: Y:0.6% UV:0.0%
# [libx264 @ 0x557f7762f0c0] ref P L0: 68.4% 16.0% 12.3%  3.3%  0.0%
# [libx264 @ 0x557f7762f0c0] ref B L0: 92.1%  6.1%  1.8%
# [libx264 @ 0x557f7762f0c0] ref B L1: 96.2%  3.8%
# [libx264 @ 0x557f7762f0c0] kb/s:966.45
# [aac @ 0x557f776e1ac0] Qavg: 618.780
